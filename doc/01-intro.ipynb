# %% [markdown]
# # Introducción
# ---

# %% [markdown]
# ## ¿Qué es la programación?
# ---

# %% [markdown]
# * Es el proceso de **codificar un algoritmo** en un lenguaje de programación
# * Es una habilidad que se adquiere mejor con la **práctica** y el **ejemplo** más que con los libros (Alan Turing)

# %% [markdown]
# ![programacion.png](attachment:4cdc6f53-7656-4daf-a24a-5a2f7d77ca0a.png)

# %% [markdown]
# ## ¿Cuáles son las ramas de la programación?
# ---

# %% [markdown]
# * Desarrollo Web
# * Desarrollo Movil
# * Videojuegos
# * Seguridad Informática
# * QA automation (pruebas automáticas)
# * Procesos automáticos
# * Inteligencia Artificial
# * Ciencia de Datos

# %% [markdown]
# ## ¿Qué hace un programador?
# ---

# %% [markdown]
# * Crear soluciones tecnológicas que satisfagan las necesidades de los usuarios
#
# 1. **Diseñar**: el código necesita una estructura ordenada que asegure su funcionamiento
# 2. **Testear**: se prueba el software en busca de posibles errores de funcionamiento
# 3. **Depurar**: diagnóstico y arreglo de errores
#
# * Se espera un código: **Eficiente, Robusto, Legible, Confiable**

# %% [markdown]
# ## ¿Qué es un algoritmo?
# ---

# %% [markdown]
# * Es la secuencia de pasos que resuelven un problema
# * Debe ser preciso, finito y legible
# * Partes:
#
# |                |                           |
# | --             | --                        |
# | **1. Entrada** | datos                     |
# | **2. Proceso** | operaciones con los datos |
# | **3. Salida**  | resultado                 |

# %% [markdown]
# ![algoritmo.jpg](attachment:014bb388-af44-4c37-8d35-4db0c02e2fa9.jpg)

# %% [markdown]
# ## ¿Cómo se resuelve un problema?
# ---

# %% [markdown]
# 1. **Diseñar** un algoritmo para el problema
# 1. Expresar el algoritmo como un **Programa** (especificación formal de un algoritmo por medio de un lenguaje de programación)
# 1. **Ejecutar** el programa (Eficiencia + V&V)

# %% [markdown]
# ![algoritmo.png](attachment:15220b25-f370-4ff0-8923-12599710fd76.png)

# %% [markdown]
# ## ¿Cuáles son los entornos de trabajo en el desarrollo de software?
# ---

# %% [markdown]
# 1. **Desarrollo local**: lo que el programador ve en un su computadora.
# 2. **Entorno de pruebas**: los tester prueban el producto para encontrar o reportar fallas.
# 3. **Staging**: características del entorno de producción, se hacen pruebas de confiabilidad (aceptación)
# 4. **Entorno de producción**

# %% [markdown]
# ## ¿Qué son los paradigmas de programación?
# ---

# %% [markdown]
# * Son los diferentes estilos de usar la programación para resolver un problema
# * Es un modelo que brinda reglas que permiten abstraer la realidad
# * Metaparadigmas: **O**peracionales (COMO) y **D**eclarativos (QUE)
#
# | Paradigma      | Meta | Características                                                             | Lenguajes                                     |
# | --             | --   | --                                                                          | --                                            |
# | **Imperativo** | O    | secuencia, ciclos y condiciones. Mutación de variables                      | Fortran, C, Pascal, COBOL, ...                |
# | **Objetos**    | O    | objetos que tiene datos y comportamiento y se comunican enviándose mensajes | Java, Python, C++, C#, Eiffel, Smalltack, ... |
# | **Funcional**  | D    | funciones que no manejan datos mutables o estados                           | Lisp, Haskell, ...                            |
# | **Lógico**     | D    | reglas y hechos basados en la lógica de predicado                           | Prolog y dialectos, ...                       |

# %% [markdown]
# ## ¿Qué es un lenguaje de programación?
# ---
#
# * Es una notación para escribir programas
# * Proporcionan estructuras:
#
# |                 |                             |
# | --              | --                          |
# | **sintácticas** | cómo escribir una expresión |
# | **semánticas**  | cómo evaluar una expresión  |

# %% [markdown]
# ## Genealogía de los lenguajes de programación
# ---

# %% [markdown]
# ![genealogia.png](attachment:6cf9813e-118c-4ab2-8a61-2b862ebc4f87.png)

# %% [markdown]
# * A partir de los ‘90 proliferan con gran éxito la tecnología y LOO
# * Los más implantados en la actualidad: Java, Python, C++, C#, ...

# %% [markdown]
# ## Aprender con ejemplos
# ---

# %%
print('Hola mundo!')
# Out:
# Hola mundo!

# %% [markdown]
# ## Aprender pensando en los tests
# ---

# %% [markdown]
# ![tdd.jpg](attachment:76dd5dec-52d1-4f9f-8ffc-9de19f6f8952.jpg)

# %% [markdown]
# ## Aprender paso a paso
# ---
#
# * Sintaxis básica
# * Estructuras de datos
# * Librerias
# * Más...
