# %% [markdown]
# # UNIVERSIDAD NACIONAL DEL OESTE
# ## Escuela de Informática
# ### PROGRAMACIÓN CON OBJETOS I
# #### Profesores: Mag. Ing. Pablo Pandolfo / Lic. Leandro Politano
# #### Examen Final - Febrero 2026

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# 1. El ____________________ en programación orientada a objetos permite que varias clases distintas usen el mismo nombre de método, ejecutando comportamientos diferentes según el objeto que lo invoque.

# %% [markdown]
# 2. El ____________________ tiene como finalidad proteger los datos del objeto, limitando el acceso directo y permitiendo interactuar mediante métodos controlados.

# %% [markdown]
# 3. La ____________________ permite que una clase reutilice atributos y comportamientos de otra, creando especializaciones o extensiones más específicas.

# %% [markdown]
# 4. Un ____________________ es una colección que organiza información mediante pares clave–valor, asegurando que cada clave sea única.

# %% [markdown]
# 5. Las ____________________ permiten agrupar elementos, incluidos objetos, facilitando la organización, acceso y manipulación de conjuntos de datos relacionados dentro de un programa.

# %% [markdown]
# 6. Al abrir un archivo en modo "w" (por ejemplo, utilizando FileWriter), el contenido anterior se elimina y el archivo se sobrescribe desde cero. Este comportamiento se conoce como modo de ____________________.

# %% [markdown]
# 7. El bloque ____________________ se utiliza para delimitar un conjunto de instrucciones que podrían generar una situación excepcional durante su ejecución.

# %% [markdown]
# 8. Crear un método que dada una lista de palabras, devuelva un mapa o diccionario que contabilice la cantidad de letras.
#     **lista = ["la","casa", "es", "linda"] => {"l":2, "a":4, "c":1,"s":2, "e":1, "i":1, "n":1, "d":1}**

# %% [markdown]
# 9. Modele una jerarquía de clases compuesta por una superclase y al menos una subclase.
#     - La superclase deberá definir un método que retorne una lista con los valores de sus atributos.
#     - La subclase  deberá sobrescribir dicho método para incluir tanto los atributos heredados como los propios.

# %% [markdown]
# 10. Crear el método *buscar_mensaje_en_archivo(palabra, nombre_archivo)* que devuelva un valor booleano, evaluando si la palabra se encuentra o no en el archivo.

# %% [markdown]
# ## Puntaje

# %% [markdown]
# * 6   -> 4/5
# * 7   -> 6/7
# * 8   -> 8
# * 9   -> 9
# * 10  -> 10
