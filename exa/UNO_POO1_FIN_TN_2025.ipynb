# %% [markdown]
# # UNIVERSIDAD NACIONAL DEL OESTE
# ## Escuela de Informática
# ### PROGRAMACIÓN CON OBJETOS I
# #### Profesores: Mag. Ing. Pablo Pandolfo / Lic. Leandro Politano
# #### Examen Final - Diciembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# 1. El polimorfismo en programación orientada a objetos hace referencia a:
#     * A- Permitir que varias clases distintas usen el mismo nombre de método, ejecutando comportamientos diferentes según el objeto que lo invoque.
#     * B- Convertir una clase en otra automáticamente sin modificar su código.
#     * C- Especificar atributos duplicados para simular que un objeto actúa como dos a la vez.
#     * D- Mezclar tipos de datos incompatibles sin errores.

# %% [markdown]
# 2. ¿Cuál de las siguientes opciones explica mejor el propósito del encapsulamiento en POO?
#     * A- Consiste en colocar todos los atributos como públicos para que otras clases puedan reutilizarlos libremente sin restricciones.
#     * B- Su objetivo principal es mejorar el rendimiento del programa al impedir que los objetos intercambien datos entre sí durante la ejecución.
#     * C- Tiene como finalidad proteger los datos del objeto limitando el acceso directo y permitiendo interactuar mediante métodos controlados.
#     * D- Se aplica únicamente en sistemas bancarios o financieros, donde la información es extremadamente sensible.

# %% [markdown]
# 3. ¿Qué afirmación describe mejor el concepto de herencia?
#     * A- Es el proceso mediante el cual una clase nueva reemplaza completamente a otra anterior, eliminándola del proyecto.
#     * B- Permite que una clase reutilice atributos y comportamientos de otra, creando especializaciones o extensiones más específicas.
#     * C- Obliga a que todas las clases dentro del programa se relacionen jerárquicamente sin excepción.
#     * D- Es un mecanismo exclusivo para interfaces gráficas que reutilizan botones y formularios.

# %% [markdown]
# 4. ¿Qué opción describe correctamente un diccionario/mapa?
#     * A- Una estructura que almacena datos únicamente en forma secuencial.
#     * B- Una colección que organiza información mediante pares clave–valor, asegurando que cada clave sea única.
#     * C- Una colección que puede tener valores duplicados pero no claves.
#     * D- Un tipo de objeto que solo almacena variables privadas.

# %% [markdown]
# 5. ¿Cuál de las siguientes afirmaciones describe correctamente el uso de colecciones dentro del paradigma orientado a objetos?
#     * A- Las colecciones solo se utilizan cuando no existen clases definidas, ya que si hay objetos creados no es necesario almacenar múltiples valores.
#     * B- Las colecciones reemplazan completamente la necesidad de crear clases, ya que su estructura permite almacenar cualquier tipo de información sin necesidad de diseño previo.
#     * C- Las colecciones únicamente pueden almacenar datos primitivos, por lo que no pueden contener instancias de clases definidas por el usuario.
#     * D- Las colecciones permiten agrupar elementos, incluidos objetos, facilitando la organización, acceso y manipulación de conjuntos de datos relacionados dentro de un programa.

# %% [markdown]
# 6. Cuando se abre un archivo utilizando el modo "w" o FileWriter, ¿qué sucede con su contenido?
#     * A- El archivo se abre exclusivamente para lectura, impidiendo agregar o modificar datos.
#     * B- Se agrega nueva información al final del archivo sin afectar los datos existentes.
#     * C- Se borra el contenido anterior del archivo y se escribe desde cero, creando el archivo si no existe.
#     * D- Se crea una copia de seguridad del archivo antes de escribir en él de manera automática.

# %% [markdown]
# 7. ¿Para qué se utiliza un bloque try en el manejo de errores en programación?
#     * A- Para asegurar que una sección del código se ejecute repetidamente hasta que no ocurran errores.
#     * B- Para delimitar un conjunto de instrucciones que podrían generar una situación excepcional durante su ejecución.
#     * C- Para registrar automáticamente todos los errores en un archivo externo.
#     * D- Para finalizar la ejecución del programa cuando se detecta un error.

# %% [markdown]
# 8. Crear un método que busque un elemento en una colección y devuelva valor booleano si lo encontró o no.

# %% [markdown]
# 9. Ejemplicar un constructor que reciba 3 parámetros y mostrar su invocación.

# %% [markdown]
# 10. Crear un método llamado guardar_mensaje(texto), que reciba un texto y lo escriba en un archivo llamado log.txt, agregando el texto al final del archivo sin eliminar el contenido previo.

# %% [markdown]
# ## Puntaje

# %% [markdown]
# * 6   -> 4/5
# * 7   -> 6/7
# * 8   -> 8
# * 9   -> 9
# * 10  -> 10
