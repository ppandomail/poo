# %% [markdown]
# # Minuta

# %% [markdown]
# * **Fecha**: 12/03/2026
# * **Lugar**: Meet
# * **Objetivo**: Unificar criterios y validar decisiones anteriores
# * **Participantes**: Leonardo Blautzik, Roberto Guglielmino, Leandro Politano, Maximiliano Sosa, Pablo Pandolfo

# %% [markdown]
# ## Repositorio Oficial y Obligatorio

# %% [markdown]
# [https://github.com/ppandomail/poo](https://github.com/ppandomail/poo)

# %% [markdown]
# ## Mantenimiento Repositorio

# %% [markdown]
# * ABM del contenido del repo lo charlamos previamente por Whatsapp y si estamos de acuerdo Pablo actualiza los cambios

# %% [markdown]
# ## Otros Repos GIT

# %% [markdown]
# * Cada comisión puede trabajar con sus propios repos de práctica

# %% [markdown]
# ## Lenguajes e IDEs

# %% [markdown]
# * Java - Eclipse
# * Python - VSC
# * Presentación de los contenidos: JupyterLab

# %% [markdown]
# ## Programa / Contenidos

# %% [markdown]
# * Desde la semana nro 2, usar tests unitarios:
#     * Java - JUnit
#     * Python- Unittest

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# * Otros ejercicios enviar a Pablo para que los suba al repo oficial

# %% [markdown]
# ## Cronograma

# %% [markdown]
# * La estructura OK, respecto a temas, semanas de parciales y semana de recuperatorios (último día de clase). Mismo tiempo para hacer el integrador

# %% [markdown]
# ## Condiciones para regularizar y promocionar

# %% [markdown]
# * Ver README del repo

# %% [markdown]
# ## Avisos

# %% [markdown]
# * Comunicaciones oficiales en **CAMPUS** y WHATSAPP
